# %%
import requests, pymongo

url = "https://api.coingecko.com/api/v3/coins/markets"
params = {"vs_currency": "usd", "order": "market_cap_desc", "per_page": 50, "page": 1}
data = requests.get(url, params=params).json()

# %%
data
# Out:
# [{'id': 'bitcoin',
#   'symbol': 'btc',
#   'name': 'Bitcoin',
#   'image': 'https://coin-images.coingecko.com/coins/images/1/large/bitcoin.png?1696501400',
#   'current_price': 112273,
#   'market_cap': 2238511770992,
#   'market_cap_rank': 1,
#   'fully_diluted_valuation': 2238511770992,
#   'total_volume': 199406698178,
#   'high_24h': 122359,
#   'low_24h': 105896,
#   'price_change_24h': -9235.801247733936,
#   'price_change_percentage_24h': -7.60094,
#   'market_cap_change_24h': -184925600420.3042,
#   'market_cap_change_percentage_24h': -7.63072,
#   'circulating_supply': 19932790.0,
#   'total_supply': 19932790.0,
#   'max_supply': 21000000.0,
#   'ath': 126080,
#   'ath_change_percentage': -10.90349,
#   'ath_date': '2025-10-06T18:57:42.558Z',
#   'atl': 67.81,
#   'atl_change_percentage': 165560.58106,
#   'atl_date': '2013-07-06T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2025-10-11T12:17:13.412Z'},
#  {'id': 'ethereum',
#   'symbol': 'eth',
# ...

# %%
data[0]
# Out:
# {'id': 'bitcoin',
#  'symbol': 'btc',
#  'name': 'Bitcoin',
#  'image': 'https://coin-images.coingecko.com/coins/images/1/large/bitcoin.png?1696501400',
#  'current_price': 112273,
#  'market_cap': 2238511770992,
#  'market_cap_rank': 1,
#  'fully_diluted_valuation': 2238511770992,
#  'total_volume': 199406698178,
#  'high_24h': 122359,
#  'low_24h': 105896,
#  'price_change_24h': -9235.801247733936,
#  'price_change_percentage_24h': -7.60094,
#  'market_cap_change_24h': -184925600420.3042,
#  'market_cap_change_percentage_24h': -7.63072,
#  'circulating_supply': 19932790.0,
#  'total_supply': 19932790.0,
#  'max_supply': 21000000.0,
#  'ath': 126080,
#  'ath_change_percentage': -10.90349,
#  'ath_date': '2025-10-06T18:57:42.558Z',
#  'atl': 67.81,
#  'atl_change_percentage': 165560.58106,
#  'atl_date': '2013-07-06T00:00:00.000Z',
#  'roi': None,
#  'last_updated': '2025-10-11T12:17:13.412Z'}

# %%
client = pymongo.MongoClient("mongodb+srv://hmafzal:mypassword123@insurance.wsoc6cn.mongodb.net/?retryWrites=true&w=majority&appName=insurance")

# %% [markdown]
# # it is creating a database (crypto_db), then a collection (crypto_market) inside it,
# # and finally saving lots of data (from the API) into that collection.

# %%
db = client["crypto_db"]
collection = db["crypto_market"]
collection.insert_many(data)

# %% [markdown]
# ## Query MongoDB to show me the top 5 coins by market cap.

# %%
# Find all documents, sort by market_cap descending (-1), and limit to 5
top5 = collection.find().sort("market_cap", -1).limit(5)

# Print them out nicely
for coin in top5:
    print(coin["name"], coin["market_cap"])
# Out:
# Bitcoin 2238511770992
# Ethereum 462648663253
# Tether 179364801296
# BNB 157053619704
# XRP 148168797558
